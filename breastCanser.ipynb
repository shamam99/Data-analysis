# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pr=pd.read_csv('bb.csv')
pr
# Out:
#        patient_id  gender   education  treatment_data  id_healthcenter  \
# 0    111038163288        0          4            2019       1110000306
# 1    111038152771        0          3            2019       1110000126
# 2    111038175699        0          2            2019       1110000311
# 3    111038141164        0          3            2019       1110000077
# 4    111038158630        0          1            2019       1110000048
# ..            ...      ...        ...             ...              ...
# 345  111038139813        1          0            2019       1110000224
# 346  111038120692        1          1            2019       1110000244
# 347  111038141274        1          7            2019       1110000018
# 348  111038127684        1          5            2019       1110000262
# 349  111038175873        1          3            2019       1110000303
#
#      id_treatment_region  hereditary_history  birth_date  age  weight  ...  \
# ...

# %%
pr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   patient_id                           350 non-null    int64
#  1   gender                               350 non-null    int64
#  2   education                            350 non-null    int64
#  3   treatment_data                       350 non-null    int64
#  4   id_healthcenter                      350 non-null    int64
#  5   id_treatment_region                  350 non-null    int64
#  6   hereditary_history                   350 non-null    int64
#  7   birth_date                           350 non-null    int64
#  8   age                                  350 non-null    int64
#  9   weight                               350 non-null    int64
#  10  thickness_tumor                      350 non-null    float64
# ...

# %%
pr.isna().sum()
# Out:
# patient_id                             0
# gender                                 0
# education                              0
# treatment_data                         0
# id_healthcenter                        0
# id_treatment_region                    0
# hereditary_history                     0
# birth_date                             0
# age                                    0
# weight                                 0
# thickness_tumor                        0
# marital_status                         0
# marital_length                         0
# pregnency_experience                   0
# giving_birth                           0
# age_FirstGivingBirth                   0
# \nabortion                             0
# blood                                  0
# taking_heartMedicine                   0
# taking_blood_pressure_medicine         0
# taking_gallbladder_disease_medicine    0
# smoking                                0
# alcohol                                0
# ...

# %%
sns.heatmap(pr.isna())
# Out:
# <AxesSubplot:>

# %%
pr.rename(columns={'patient_id':'p_id'},inplace=True)

# %%
pr.rename(columns={'gender':'sex'},inplace=True)

# %%
pr['\nmenopausal_age'] = pr['\nmenopausal_age'].fillna(pr['\nmenopausal_age'].mean())

# %%
pr.isnull()
# Out:
#       p_id  gender   education  treatment_data  id_healthcenter  \
# 0    False    False      False           False            False
# 1    False    False      False           False            False
# 2    False    False      False           False            False
# 3    False    False      False           False            False
# 4    False    False      False           False            False
# ..     ...      ...        ...             ...              ...
# 345  False    False      False           False            False
# 346  False    False      False           False            False
# 347  False    False      False           False            False
# 348  False    False      False           False            False
# 349  False    False      False           False            False
#
#      id_treatment_region  hereditary_history  birth_date    age  weight  ...  \
# 0                  False               False       False  False   False  ...
# ...

# %%
pr.describe()
# Out:
#                p_id     gender    education  treatment_data  id_healthcenter  \
# count  3.500000e+02  350.000000  350.000000           350.0     3.500000e+02
# mean   1.110382e+11    0.225714    2.811429          2019.0     1.110000e+09
# std    1.834764e+04    0.418650    1.844650             0.0     1.014865e+02
# min    1.110381e+11    0.000000    0.000000          2019.0     1.110000e+09
# 25%    1.110381e+11    0.000000    1.000000          2019.0     1.110000e+09
# 50%    1.110382e+11    0.000000    3.000000          2019.0     1.110000e+09
# 75%    1.110382e+11    0.000000    4.000000          2019.0     1.110000e+09
# max    1.110382e+11    1.000000    7.000000          2019.0     1.110000e+09
#
#        id_treatment_region  hereditary_history   birth_date         age  \
# count         3.500000e+02          350.000000   350.000000  350.000000
# mean          1.110000e+09            0.614286  1981.068571   37.931429
# ...

# %%
sns.heatmap(pr.isna())
# Out:
# <AxesSubplot:>

# %%
pr.describe().round()
# Out:
#                p_id  gender   education  treatment_data  id_healthcenter  \
# count  3.500000e+02    350.0      350.0           350.0     3.500000e+02
# mean   1.110382e+11      0.0        3.0          2019.0     1.110000e+09
# std    1.834800e+04      0.0        2.0             0.0     1.010000e+02
# min    1.110381e+11      0.0        0.0          2019.0     1.110000e+09
# 25%    1.110381e+11      0.0        1.0          2019.0     1.110000e+09
# 50%    1.110382e+11      0.0        3.0          2019.0     1.110000e+09
# 75%    1.110382e+11      0.0        4.0          2019.0     1.110000e+09
# max    1.110382e+11      1.0        7.0          2019.0     1.110000e+09
#
#        id_treatment_region  hereditary_history  birth_date    age  weight  \
# count         3.500000e+02               350.0       350.0  350.0   350.0
# mean          1.110000e+09                 1.0      1981.0   38.0    74.0
# std           1.000000e+00                 0.0        14.0   14.0    21.0
# ...

# %%
pr.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 345    False
# 346    False
# 347    False
# 348    False
# 349    False
# Length: 350, dtype: bool

# %%
pr
# Out:
#              p_id  gender   education  treatment_data  id_healthcenter  \
# 0    111038163288        0          4            2019       1110000306
# 1    111038152771        0          3            2019       1110000126
# 2    111038175699        0          2            2019       1110000311
# 3    111038141164        0          3            2019       1110000077
# 4    111038158630        0          1            2019       1110000048
# ..            ...      ...        ...             ...              ...
# 345  111038139813        1          0            2019       1110000224
# 346  111038120692        1          1            2019       1110000244
# 347  111038141274        1          7            2019       1110000018
# 348  111038127684        1          5            2019       1110000262
# 349  111038175873        1          3            2019       1110000303
#
#      id_treatment_region  hereditary_history  birth_date  age  weight  ...  \
# ...

# %%
num = pr._get_numeric_data()

# %%
num
# Out:
#              p_id  gender   education  treatment_data  id_healthcenter  \
# 0    111038163288        0          4            2019       1110000306
# 1    111038152771        0          3            2019       1110000126
# 2    111038175699        0          2            2019       1110000311
# 3    111038141164        0          3            2019       1110000077
# 4    111038158630        0          1            2019       1110000048
# ..            ...      ...        ...             ...              ...
# 345  111038139813        1          0            2019       1110000224
# 346  111038120692        1          1            2019       1110000244
# 347  111038141274        1          7            2019       1110000018
# 348  111038127684        1          5            2019       1110000262
# 349  111038175873        1          3            2019       1110000303
#
#      id_treatment_region  hereditary_history  birth_date  age  weight  ...  \
# ...

# %%
pr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   p_id                                 350 non-null    int64
#  1   gender                               350 non-null    int64
#  2   education                            350 non-null    int64
#  3   treatment_data                       350 non-null    int64
#  4   id_healthcenter                      350 non-null    int64
#  5   id_treatment_region                  350 non-null    int64
#  6   hereditary_history                   350 non-null    int64
#  7   birth_date                           350 non-null    int64
#  8   age                                  350 non-null    int64
#  9   weight                               350 non-null    int64
#  10  thickness_tumor                      350 non-null    float64
# ...

# %% [markdown]
# # Analyzes the ages?

# %%
pr['age'].value_counts()
# Out:
# 33    22
# 31    22
# 39    18
# 24    14
# 32    14
#       ..
# 70     1
# 71     1
# 74     1
# 79     1
# 2      1
# Name: age, Length: 67, dtype: int64

# %% [markdown]
# # Analyzes the education?

# %%
pr['education'].value_counts()
# Out:
# 4    98
# 1    80
# 2    51
# 0    34
# 3    32
# 6    29
# 5    21
# 7     5
# Name: education, dtype: int64

# %% [markdown]
# # Analysis of patients who smoke?

# %%
pr['smoking'].value_counts()
# Out:
# 0    232
# 1    118
# Name: smoking, dtype: int64

# %% [markdown]
# # Analysis about patients blood?

# %%
pr['blood'].value_counts()
# Out:
# 0    89
# 1    63
# 2    51
# 6    39
# 4    39
# 3    37
# 7    21
# 5    11
# Name: blood, dtype: int64

# %% [markdown]
# # Analysis of patients who  drink alcohol?

# %%
pr['alcohol'].value_counts()
# Out:
# 0    186
# 1    164
# Name: alcohol, dtype: int64

# %% [markdown]
# # Analysis the birth date of patients ?

# %%
pr['birth_date'].value_counts()
# Out:
# 1988    22
# 1986    22
# 1980    18
# 1995    14
# 1987    14
#         ..
# 2003     1
# 2006     1
# 2007     1
# 2010     1
# 1933     1
# Name: birth_date, Length: 67, dtype: int64

# %% [markdown]
# # Analysis the marital status ?

# %%
pr['marital_status'].value_counts()
# Out:
# 1    238
# 0    112
# Name: marital_status, dtype: int64

# %% [markdown]
# # Analysis the breast pain of patients?

# %%
pr['breast_pain'].value_counts()
# Out:
# 1    246
# 0    104
# Name: breast_pain, dtype: int64

# %%
sns.countplot(x='breast_pain',data=pr,palette='pastel')
# Out:
# <AxesSubplot:xlabel='breast_pain', ylabel='count'>

# %%
num=pr._get_numeric_data()

# %%
num
# Out:
#              p_id  gender   education  treatment_data  id_healthcenter  \
# 0    111038163288        0          4            2019       1110000306
# 1    111038152771        0          3            2019       1110000126
# 2    111038175699        0          2            2019       1110000311
# 3    111038141164        0          3            2019       1110000077
# 4    111038158630        0          1            2019       1110000048
# ..            ...      ...        ...             ...              ...
# 345  111038139813        1          0            2019       1110000224
# 346  111038120692        1          1            2019       1110000244
# 347  111038141274        1          7            2019       1110000018
# 348  111038127684        1          5            2019       1110000262
# 349  111038175873        1          3            2019       1110000303
#
#      id_treatment_region  hereditary_history  birth_date  age  weight  ...  \
# ...

# %%
sns.countplot(x='smoking',data=pr,palette='pastel',hue='treatment_data')
# Out:
# <AxesSubplot:xlabel='smoking', ylabel='count'>

# %%
sns.countplot(x='alcohol',data=pr,palette='pastel',hue='treatment_data')
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='count'>

# %%
pr['age'].plot(kind='hist',figsize=(10,3), title='age of patient')
# Out:
# <AxesSubplot:title={'center':'age of patient'}, ylabel='Frequency'>

# %%
pr =pd.DataFrame(np.random.rand(10,4),columns=["a=birth_date","b=age","c=taking_gallbladder_disease_medicine","d=breast_pain"])
pr.plot.area()
# Out:
# <AxesSubplot:>

# %%
 from matplotlib import cm
plt.figure()
pr.plot(colormap=cm.cubehelix)
# Out:
# <AxesSubplot:>
